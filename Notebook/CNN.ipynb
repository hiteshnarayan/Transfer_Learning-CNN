# %% [markdown]
# <h4>
# <center> <u>Name:</u> Hitesh Narayana </center><br>
# <center> <u>Github username:</u> Hit07 </center><br>
# <center> <u>USC ID:</u> 9478372848 </center>
# </h4>

# %% [markdown]
# ## Import Statements

# %%
import os
import zipfile
from PIL import Image
import numpy as np
from google.colab import drive
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.applications import ResNet50, ResNet101, EfficientNetB0, VGG16
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_auc_score
import warnings
warnings.filterwarnings('ignore', category=UserWarning)
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
# Mount Google Drive
drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/DSCI552_Final_Project')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi 2>&1 | grep -i "cuda"
# !nvidia-smi
# Out:
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# Sat Dec 14 01:29:02 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   29C    P0              45W / 400W |      2MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## **b) Data Exploration and Pre-processing**
#
# Images in each class are given in separate folders in the training and test sets. You can encode your classes using one-hot encoding. In case all the images do not have the same size, zero-pad or resize the images
# in your dataset. This can be done using various tools, including OpenCV.

# %% [markdown]
# - We define the class labels for our dataset and extract the images from the zip files for both the training and test datasets. Each class has its own zip file, and the images are extracted into separate directories for each class.
# - We create a subplot to visualize a sample image from each class. We also print the number of training and test images for each class. This helps in understanding the distribution of images across different classes.

# %%
class_labels = ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# Extract the data/seg_test zip files and create one-hot encoded class labels
for i, zip_file in enumerate(['buildings.zip', 'forest.zip', 'glacier.zip', 'mountain.zip', 'sea.zip', 'street.zip']):
  with zipfile.ZipFile(os.path.join('seg_test', zip_file), 'r') as zip_ref:
      zip_ref.extractall(os.path.join('data', 'seg_test', str(i)))

# Extract the data/seg_train zip files and create one-hot encoded class labels
for i, zip_file in enumerate(['buildings.zip', 'forest.zip', 'glacier.zip', 'mountain.zip', 'sea.zip', 'street.zip']):
  with zipfile.ZipFile(os.path.join('seg_train', zip_file), 'r') as zip_ref:
      zip_ref.extractall(os.path.join('data', 'seg_train', str(i)))


# Display sample image from each class
fig, axes = plt.subplots(2, 3, figsize=(15, 10))
fig.suptitle('Classification Dataset', fontsize=16)
axes_flat = axes.ravel()

for i, (class_name, ax) in enumerate(zip(class_labels, axes_flat)):
  train_dir = os.path.join('data', 'seg_train', str(i))
  test_dir = os.path.join('data', 'seg_test', str(i))
  train_images = len(os.listdir(train_dir))
  test_images = len(os.listdir(test_dir))

  # Number of train and test images
  print(f"{class_name.capitalize()}:")
  print(f"  Training images: {train_images}")
  print(f"  Test images: {test_images}")

  # Display random image for reference
  sample_image_path = os.path.join(train_dir, os.listdir(train_dir)[0])
  sample_image = Image.open(sample_image_path)
  ax.imshow(sample_image)
  ax.set_title(f'{class_name}\nTrain: {train_images}, Test: {test_images}')
  ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Buildings:
#   Training images: 2191
#   Test images: 437
# Forest:
#   Training images: 2271
#   Test images: 474
# Glacier:
#   Training images: 2404
#   Test images: 553
# Mountain:
#   Training images: 2512
#   Test images: 525
# Sea:
#   Training images: 2274
#   Test images: 510
# Street:
#   Training images: 2382
#   Test images: 501

# %% [markdown]
# ## c) Transfer Learning

# %% [markdown]
# ii. To perform empirical regularization, crop, randomly zoom, rotate, flip, con-
# trast, and translate images in your training set for image augmentation. You
# can use various tools to do this, including OpenCV.

# %% [markdown]
# #### Data Augmentation

# %%
with tf.device('/GPU:0'):

    '''Data augmentation to enhance the training dataset by applying transformations
    such as rotation, zoom, and flipping:'''
    # Reference: https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator
    train_datagen = ImageDataGenerator(
        rescale=1.0/255,
        rotation_range=20, # Rotate
        featurewise_center=False,
        samplewise_center=False,
        featurewise_std_normalization=False,
        samplewise_std_normalization=False,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.2,
        zoom_range=0.2, # Zoom
        horizontal_flip=True, # Flip
        vertical_flip=False,
        fill_mode="nearest",
        validation_split=0.2 # Validation Split
    )
    val_datagen = ImageDataGenerator(rescale=1.0/255,validation_split=0.2)
    test_datagen = ImageDataGenerator(rescale=1.0 / 255)


    '''I'm using batch size of 32 and setting image size to standard 224*224'''
    # Data generators
    train_generator = train_datagen.flow_from_directory(
        "data/seg_train",
        target_size=(224, 224),
        batch_size=32,
        class_mode="categorical",
        shuffle=True,
        subset="training"
    )

    validation_generator = val_datagen.flow_from_directory(
        "data/seg_train",
        target_size=(224, 224),
        batch_size=32,
        class_mode="categorical",
        shuffle=False,
        subset="validation"
    )

    test_generator = test_datagen.flow_from_directory(
        "data/seg_test",
        target_size=(224, 224),
        batch_size=32,
        class_mode="categorical",
        shuffle=False
    )
# Out:
# Found 11230 images belonging to 6 classes.
# Found 2804 images belonging to 6 classes.
# Found 3000 images belonging to 6 classes.

# %%
# !nvidia-smi
# Check for GPU
print("TensorFlow version:", tf.__version__)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print("CUDA Available:", tf.test.is_built_with_cuda())
print("GPU Devices:", tf.config.list_physical_devices('GPU'))
# Out:
# Sat Dec 14 01:31:13 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off | 00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0              51W / 400W |    423MiB / 40960MiB |      0%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+
# TensorFlow version: 2.17.1
# Num GPUs Available:  1
# CUDA Available: True
# GPU Devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# #### Model Creation and Model Architecture
# i. When dealing with classification of relatively small image datasets, deep net-
# works may not perform very well because of not having enough data to train
# them. In such cases, one usually uses transfer learning, which uses deep
# learning models that are trained on very large datasets such as ImageNet
# as feature extractors. The idea is that such deep networks have learned to
# extract meaningful features from an image using their layers, and those fea-
# tures can be used in learning other tasks. In order to do that, usually the
# last layer or the last few layers of the pre-trained network are removed, and
# the response of the layer before the removed layers to the images in the new
# dataset is used as a feature vector to train one more multiple replacement lay-
# ers. In this project, you will use pre-trained models ResNet50, ResNet100,
# EfficientNetB0, and VGG16. For those pre-trained networks, you will only
# train the last fully connected layer, and will freeze all layers before them (i.e.
# we do not change their parameters during training) and use the outputs of the
# penultimate layer in the original pre-trained model as the features extracted
# from each image.

# %% [markdown]
# iii. Use ReLU activation functions in the last layer and a softmax layer, along
# with 2 regularization, batch normalization 4, and a dropout rate of 20% as
# well as ADAM optimizer. Use multinomial cross entropy loss. You can try
# any batch size, but a batch size of 5 seems reasonable.

# %%
# Reference: https://www.tensorflow.org/guide/keras/transfer_learning
def create_model(base_model_class, learning_rate=1e-4):
    base_model = base_model_class(weights="imagenet", include_top=False, input_shape=(224, 224, 3)) # Using input shape after rescaling to 224*224*3 for color channel RGB
    # Freeze layers expect the last layer
    for layer in base_model.layers:
        layer.trainable = False

    # Building the Model
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(), # Average Pooling
        BatchNormalization(momentum=0.9), # BatchNormalization
        Dropout(0.2), # Random dropout to avoid Overfitting
        Dense(256, activation="relu", kernel_regularizer=l2(0.001)), # Using l2 metric to avoid overfitting
        Dense(6, activation="softmax")
    ])

    model.compile(
        optimizer=Adam(learning_rate=learning_rate), # Custom lr for each model
        loss="categorical_crossentropy", # Categorical data
        metrics=["accuracy"]
    )

    return model

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### Define Custom Callbacks
# Find more on it [here](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/Callback)

# %%
def get_callbacks(model_name):
    return [
        # Reduce the learning rate when a metric has stopped improving
        ReduceLROnPlateau(
            monitor='val_loss',  # Monitor validation loss
            factor=0.3,          # Factor by which the learning rate will be reduced
            patience=5,          # Number of epochs with no improvement after which learning rate will be reduced
            min_lr=1e-6,
            verbose=1
        ),
        # Stop training when a monitored metric has stopped improving
        EarlyStopping(
            monitor='val_loss',
            patience=7,          # Number of epochs with no improvement after which training will be stopped
            restore_best_weights=True,  # Restore model weights from the epoch with the best value of the monitored quantity
            verbose=1
        ),
        # Save the model after every epoch
        ModelCheckpoint(
            filepath=f"{model_name}_best_model_epoch_{{epoch:02d}}.keras",  # Filepath to save the model
            monitor='val_loss',
            mode='min',          # Mode for monitoring the quantity
            save_freq=10,        # Save the model every 10 epochs
            verbose=1
        )
    ]

# %% [markdown]
# #### Model Training
#
# vi. Train the networks for at least 50 epochs (preferably 100 epochs) and perform
# early stopping using the validation set. Use a randomly selected subset of 20%
# of each class as the validation set. Keep the network parameters that have
# the lowest validation error. Plot the training and validation errors vs. epochs.

# %%
def train_model(model, model_name, train_generator, validation_generator):
    callbacks = get_callbacks(model_name)

    print(f"\n--- Training {model_name} Model ---")
    history = model.fit(
        train_generator,
        validation_data=validation_generator,
        epochs=50, # I'm using 50 epochs
        callbacks=callbacks,
        verbose=1
    )

    return history

# %% [markdown]
# ### Model Evaluation
# These functions are used to evaluate a trained model on a test dataset and to plot the learning curves of the model during training, respectively.

# %%
def evaluate_model(model, test_generator, model_name):
    print(f"\n--- Evaluating {model_name} Set ---")
    loss, accuracy = model.evaluate(test_generator, verbose=1)

    # Predict the classes for the test dataset
    y_pred = model.predict(test_generator)
    y_true = test_generator.classes
    y_pred_classes = np.argmax(y_pred, axis=1)

    precision = precision_score(y_true, y_pred_classes, average='weighted')
    recall = recall_score(y_true, y_pred_classes, average='weighted')
    f1 = f1_score(y_true, y_pred_classes, average='weighted')

    # Calculate AUC for multi-class
    auc = roc_auc_score(tf.keras.utils.to_categorical(y_true), y_pred, average='weighted', multi_class='ovr')

    print(f"\nMetrics for {model_name} Set:")
    print(f"Loss: {loss:,.3f}")
    print(f"Accuracy: {accuracy:.3f}")
    print(f"Precision: {precision:.3f}")
    print(f"Recall: {recall:.3f}")
    print(f"F1 Score: {f1:.3f}")
    print(f"AUC: {auc:.3f}")


    return loss, accuracy, precision, recall, f1, auc

"""Plot training and validation accuracy and loss curves."""
def plot_learning_curves(history, model_name):
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title(f'{model_name} - Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f'{model_name} - Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### RestNet50

# %%
def train_resnet50(train_generator, validation_generator, test_generator):
    tf.keras.backend.clear_session()
    with tf.device('/GPU:0'):
      # Create
      model = create_model(ResNet50, learning_rate=1e-4)
      # Train
      history = train_model(model, "ResNet50", train_generator, validation_generator)
      # Evaluate and plot
      metrics = evaluate_model(model, test_generator, "ResNet50")
      plot_learning_curves(history, "ResNet50")

      return model, history, metrics

resnet50_model, resnet50_history, resnet50_metrics = train_resnet50(train_generator, validation_generator, test_generator)
# Out:
# --- Training ResNet50 Model ---
# Epoch 1/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 164s 433ms/step - accuracy: 0.4192 - loss: 1.7918 - val_accuracy: 0.6277 - val_loss: 1.2224 - learning_rate: 1.0000e-04
# Epoch 2/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 147s 412ms/step - accuracy: 0.5395 - loss: 1.3630 - val_accuracy: 0.6505 - val_loss: 1.1080 - learning_rate: 1.0000e-04
# Epoch 3/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 147s 412ms/step - accuracy: 0.5704 - loss: 1.2625 - val_accuracy: 0.6605 - val_loss: 1.0522 - learning_rate: 1.0000e-04
# Epoch 4/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 147s 411ms/step - accuracy: 0.5902 - loss: 1.2010 - val_accuracy: 0.6694 - val_loss: 1.0285 - learning_rate: 1.0000e-04
# Epoch 5/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 407ms/step - accuracy: 0.5990 - loss: 1.1670 - val_accuracy: 0.6787 - val_loss: 0.9945 - learning_rate: 1.0000e-04
# Epoch 6/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 407ms/step - accuracy: 0.5965 - loss: 1.1413 - val_accuracy: 0.6801 - val_loss: 0.9747 - learning_rate: 1.0000e-04
# Epoch 7/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6183 - loss: 1.1169 - val_accuracy: 0.6815 - val_loss: 0.9622 - learning_rate: 1.0000e-04
# Epoch 8/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6227 - loss: 1.1040 - val_accuracy: 0.6790 - val_loss: 0.9616 - learning_rate: 1.0000e-04
# Epoch 9/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 407ms/step - accuracy: 0.6143 - loss: 1.1109 - val_accuracy: 0.7011 - val_loss: 0.9192 - learning_rate: 1.0000e-04
# Epoch 10/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6297 - loss: 1.0741 - val_accuracy: 0.6965 - val_loss: 0.9288 - learning_rate: 1.0000e-04
# Epoch 11/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 407ms/step - accuracy: 0.6365 - loss: 1.0731 - val_accuracy: 0.7068 - val_loss: 0.9080 - learning_rate: 1.0000e-04
# Epoch 12/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6343 - loss: 1.0666 - val_accuracy: 0.7058 - val_loss: 0.9149 - learning_rate: 1.0000e-04
# Epoch 13/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 404ms/step - accuracy: 0.6356 - loss: 1.0663 - val_accuracy: 0.7026 - val_loss: 0.8967 - learning_rate: 1.0000e-04
# Epoch 14/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6355 - loss: 1.0612 - val_accuracy: 0.6969 - val_loss: 0.8911 - learning_rate: 1.0000e-04
# Epoch 15/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 404ms/step - accuracy: 0.6264 - loss: 1.0597 - val_accuracy: 0.7083 - val_loss: 0.8847 - learning_rate: 1.0000e-04
# Epoch 16/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6376 - loss: 1.0387 - val_accuracy: 0.7058 - val_loss: 0.8893 - learning_rate: 1.0000e-04
# Epoch 17/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.6335 - loss: 1.0434 - val_accuracy: 0.7022 - val_loss: 0.8783 - learning_rate: 1.0000e-04
# Epoch 18/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.6382 - loss: 1.0198 - val_accuracy: 0.7215 - val_loss: 0.8518 - learning_rate: 1.0000e-04
# Epoch 19/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.6399 - loss: 1.0294 - val_accuracy: 0.7015 - val_loss: 0.8812 - learning_rate: 1.0000e-04
# Epoch 20/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 404ms/step - accuracy: 0.6372 - loss: 1.0284 - val_accuracy: 0.7058 - val_loss: 0.8689 - learning_rate: 1.0000e-04
# Epoch 21/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6372 - loss: 1.0251 - val_accuracy: 0.7136 - val_loss: 0.8616 - learning_rate: 1.0000e-04
# Epoch 22/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.6444 - loss: 1.0004 - val_accuracy: 0.7158 - val_loss: 0.8532 - learning_rate: 1.0000e-04
# Epoch 23/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 407ms/step - accuracy: 0.6419 - loss: 1.0067 - val_accuracy: 0.7190 - val_loss: 0.8469 - learning_rate: 1.0000e-04
# Epoch 24/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6515 - loss: 0.9942 - val_accuracy: 0.7136 - val_loss: 0.8525 - learning_rate: 1.0000e-04
# Epoch 25/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6520 - loss: 0.9872 - val_accuracy: 0.7175 - val_loss: 0.8364 - learning_rate: 1.0000e-04
# Epoch 26/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 407ms/step - accuracy: 0.6433 - loss: 1.0163 - val_accuracy: 0.7186 - val_loss: 0.8397 - learning_rate: 1.0000e-04
# Epoch 27/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6438 - loss: 0.9977 - val_accuracy: 0.7122 - val_loss: 0.8403 - learning_rate: 1.0000e-04
# Epoch 28/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.6491 - loss: 0.9905 - val_accuracy: 0.7122 - val_loss: 0.8328 - learning_rate: 1.0000e-04
# Epoch 29/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.6452 - loss: 0.9846 - val_accuracy: 0.7118 - val_loss: 0.8272 - learning_rate: 1.0000e-04
# Epoch 30/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6385 - loss: 1.0068 - val_accuracy: 0.7190 - val_loss: 0.8276 - learning_rate: 1.0000e-04
# Epoch 31/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.6526 - loss: 0.9821 - val_accuracy: 0.7204 - val_loss: 0.8345 - learning_rate: 1.0000e-04
# Epoch 32/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 404ms/step - accuracy: 0.6424 - loss: 0.9859 - val_accuracy: 0.7186 - val_loss: 0.8207 - learning_rate: 1.0000e-04
# Epoch 33/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.6437 - loss: 0.9892 - val_accuracy: 0.7240 - val_loss: 0.8224 - learning_rate: 1.0000e-04
# Epoch 34/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6577 - loss: 0.9705 - val_accuracy: 0.7229 - val_loss: 0.8200 - learning_rate: 1.0000e-04
# Epoch 35/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.6519 - loss: 0.9740 - val_accuracy: 0.7200 - val_loss: 0.8195 - learning_rate: 1.0000e-04
# Epoch 36/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6487 - loss: 0.9690 - val_accuracy: 0.7208 - val_loss: 0.8148 - learning_rate: 1.0000e-04
# Epoch 37/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 404ms/step - accuracy: 0.6441 - loss: 0.9845 - val_accuracy: 0.7165 - val_loss: 0.8205 - learning_rate: 1.0000e-04
# Epoch 38/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6542 - loss: 0.9690 - val_accuracy: 0.7140 - val_loss: 0.8137 - learning_rate: 1.0000e-04
# Epoch 39/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 407ms/step - accuracy: 0.6563 - loss: 0.9809 - val_accuracy: 0.7293 - val_loss: 0.8005 - learning_rate: 1.0000e-04
# Epoch 40/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.6461 - loss: 0.9804 - val_accuracy: 0.7240 - val_loss: 0.8019 - learning_rate: 1.0000e-04
# Epoch 41/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 407ms/step - accuracy: 0.6580 - loss: 0.9603 - val_accuracy: 0.7279 - val_loss: 0.7998 - learning_rate: 1.0000e-04
# Epoch 42/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 407ms/step - accuracy: 0.6558 - loss: 0.9590 - val_accuracy: 0.7322 - val_loss: 0.7979 - learning_rate: 1.0000e-04
# Epoch 43/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6597 - loss: 0.9542 - val_accuracy: 0.7379 - val_loss: 0.7936 - learning_rate: 1.0000e-04
# Epoch 44/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.6631 - loss: 0.9458 - val_accuracy: 0.7315 - val_loss: 0.7997 - learning_rate: 1.0000e-04
# Epoch 45/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 404ms/step - accuracy: 0.6635 - loss: 0.9478 - val_accuracy: 0.7318 - val_loss: 0.8023 - learning_rate: 1.0000e-04
# Epoch 46/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 404ms/step - accuracy: 0.6630 - loss: 0.9330 - val_accuracy: 0.7340 - val_loss: 0.7822 - learning_rate: 1.0000e-04
# Epoch 47/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 404ms/step - accuracy: 0.6574 - loss: 0.9581 - val_accuracy: 0.7250 - val_loss: 0.8107 - learning_rate: 1.0000e-04
# Epoch 48/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.6525 - loss: 0.9499 - val_accuracy: 0.7286 - val_loss: 0.7902 - learning_rate: 1.0000e-04
# Epoch 49/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 404ms/step - accuracy: 0.6565 - loss: 0.9555 - val_accuracy: 0.7268 - val_loss: 0.8028 - learning_rate: 1.0000e-04
# Epoch 50/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 408ms/step - accuracy: 0.6630 - loss: 0.9479 - val_accuracy: 0.7300 - val_loss: 0.7875 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 46.
#
# --- Evaluating ResNet50 Set ---
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 12s 126ms/step - accuracy: 0.7802 - loss: 0.6807
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 15s 124ms/step
#
# Metrics for ResNet50 Set:
# Loss: 0.787
# Accuracy: 0.728
# Precision: 0.731
# Recall: 0.728
# F1 Score: 0.726
# AUC: 0.944

# %% [markdown]
# - The ResNet50 model achieved a validation accuracy of 72.8% and an AUC of 0.944, indicating good performance and generalization. The model's precision, recall, and F1 score are all around 0.73, showing balanced performance across different metrics.

# %% [markdown]
# ## RestNet101
# In my implementation, I opted for ResNet101 instead of ResNet100 since ResNet101 is the standard architecture available in TensorFlow/Keras<br><hr>
# Refer for more(https://www.tensorflow.org/api_docs/python/tf/keras/applications/resnet)

# %%
def train_resnet101(train_generator, validation_generator, test_generator):
    tf.keras.backend.clear_session()
    with tf.device('/GPU:0'):
      model = create_model(ResNet101, learning_rate=5e-4)
      history = train_model(model, "ResNet101", train_generator, validation_generator)

      # Evaluate and plot
      metrics = evaluate_model(model, test_generator, "ResNet101")
      plot_learning_curves(history, "ResNet101")

      return model, history, metrics

resnet101_model, resnet101_history, resnet101_metrics = train_resnet101(train_generator, validation_generator, test_generator)
# Out:
# --- Training ResNet101 Model ---
# Epoch 1/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 173s 439ms/step - accuracy: 0.4477 - loss: 1.5681 - val_accuracy: 0.6155 - val_loss: 1.0985 - learning_rate: 5.0000e-04
# Epoch 2/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 407ms/step - accuracy: 0.5489 - loss: 1.2578 - val_accuracy: 0.6298 - val_loss: 1.0641 - learning_rate: 5.0000e-04
# Epoch 3/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.5630 - loss: 1.2088 - val_accuracy: 0.6441 - val_loss: 0.9931 - learning_rate: 5.0000e-04
# Epoch 4/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 408ms/step - accuracy: 0.5673 - loss: 1.1723 - val_accuracy: 0.6551 - val_loss: 0.9776 - learning_rate: 5.0000e-04
# Epoch 5/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.5880 - loss: 1.1455 - val_accuracy: 0.6530 - val_loss: 0.9850 - learning_rate: 5.0000e-04
# Epoch 6/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.5796 - loss: 1.1319 - val_accuracy: 0.6384 - val_loss: 0.9920 - learning_rate: 5.0000e-04
# Epoch 7/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 408ms/step - accuracy: 0.5817 - loss: 1.1366 - val_accuracy: 0.6491 - val_loss: 0.9655 - learning_rate: 5.0000e-04
# Epoch 8/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 407ms/step - accuracy: 0.5889 - loss: 1.1098 - val_accuracy: 0.6687 - val_loss: 0.9378 - learning_rate: 5.0000e-04
# Epoch 9/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 147s 409ms/step - accuracy: 0.5905 - loss: 1.1021 - val_accuracy: 0.6687 - val_loss: 0.9266 - learning_rate: 5.0000e-04
# Epoch 10/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 409ms/step - accuracy: 0.5880 - loss: 1.1108 - val_accuracy: 0.6701 - val_loss: 0.9277 - learning_rate: 5.0000e-04
# Epoch 11/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 407ms/step - accuracy: 0.5811 - loss: 1.1083 - val_accuracy: 0.6737 - val_loss: 0.9182 - learning_rate: 5.0000e-04
# Epoch 12/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 407ms/step - accuracy: 0.5895 - loss: 1.0933 - val_accuracy: 0.6740 - val_loss: 0.9238 - learning_rate: 5.0000e-04
# Epoch 13/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 407ms/step - accuracy: 0.5953 - loss: 1.1003 - val_accuracy: 0.6783 - val_loss: 0.9111 - learning_rate: 5.0000e-04
# Epoch 14/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 408ms/step - accuracy: 0.6003 - loss: 1.0843 - val_accuracy: 0.6812 - val_loss: 0.9153 - learning_rate: 5.0000e-04
# Epoch 15/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.5954 - loss: 1.0802 - val_accuracy: 0.6598 - val_loss: 0.9304 - learning_rate: 5.0000e-04
# Epoch 16/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 409ms/step - accuracy: 0.5999 - loss: 1.0887 - val_accuracy: 0.6847 - val_loss: 0.8973 - learning_rate: 5.0000e-04
# Epoch 17/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 409ms/step - accuracy: 0.6015 - loss: 1.0667 - val_accuracy: 0.6758 - val_loss: 0.9163 - learning_rate: 5.0000e-04
# Epoch 18/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 408ms/step - accuracy: 0.5957 - loss: 1.0900 - val_accuracy: 0.6633 - val_loss: 0.9275 - learning_rate: 5.0000e-04
# Epoch 19/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.5940 - loss: 1.0787 - val_accuracy: 0.6915 - val_loss: 0.8992 - learning_rate: 5.0000e-04
# Epoch 20/50
# 350/351 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.6099 - loss: 1.0560
# Epoch 20: saving model to ResNet101_best_model_epoch_20.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 147s 412ms/step - accuracy: 0.6099 - loss: 1.0561 - val_accuracy: 0.6805 - val_loss: 0.8959 - learning_rate: 5.0000e-04
# Epoch 21/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6006 - loss: 1.0647 - val_accuracy: 0.6772 - val_loss: 0.9066 - learning_rate: 5.0000e-04
# Epoch 22/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.5978 - loss: 1.0793 - val_accuracy: 0.6637 - val_loss: 0.9327 - learning_rate: 5.0000e-04
# Epoch 23/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.6036 - loss: 1.0577 - val_accuracy: 0.6665 - val_loss: 0.9267 - learning_rate: 5.0000e-04
# Epoch 24/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 408ms/step - accuracy: 0.6137 - loss: 1.0516 - val_accuracy: 0.6769 - val_loss: 0.9062 - learning_rate: 5.0000e-04
# Epoch 25/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 409ms/step - accuracy: 0.6123 - loss: 1.0649 - val_accuracy: 0.6872 - val_loss: 0.8914 - learning_rate: 5.0000e-04
# Epoch 26/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 407ms/step - accuracy: 0.6061 - loss: 1.0623 - val_accuracy: 0.6755 - val_loss: 0.8936 - learning_rate: 5.0000e-04
# Epoch 27/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.5946 - loss: 1.0575 - val_accuracy: 0.6748 - val_loss: 0.9213 - learning_rate: 5.0000e-04
# Epoch 28/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6063 - loss: 1.0646 - val_accuracy: 0.6740 - val_loss: 0.9069 - learning_rate: 5.0000e-04
# Epoch 29/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 407ms/step - accuracy: 0.6041 - loss: 1.0613 - val_accuracy: 0.6712 - val_loss: 0.9149 - learning_rate: 5.0000e-04
# Epoch 30/50
# 350/351 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.6072 - loss: 1.0780
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 404ms/step - accuracy: 0.6072 - loss: 1.0779 - val_accuracy: 0.6751 - val_loss: 0.8952 - learning_rate: 5.0000e-04
# Epoch 31/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 147s 410ms/step - accuracy: 0.6128 - loss: 1.0373 - val_accuracy: 0.6947 - val_loss: 0.8734 - learning_rate: 1.5000e-04
# Epoch 32/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 408ms/step - accuracy: 0.6185 - loss: 1.0222 - val_accuracy: 0.6897 - val_loss: 0.8576 - learning_rate: 1.5000e-04
# Epoch 33/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 408ms/step - accuracy: 0.6169 - loss: 1.0328 - val_accuracy: 0.7029 - val_loss: 0.8612 - learning_rate: 1.5000e-04
# Epoch 34/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 407ms/step - accuracy: 0.6206 - loss: 1.0232 - val_accuracy: 0.7022 - val_loss: 0.8510 - learning_rate: 1.5000e-04
# Epoch 35/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 408ms/step - accuracy: 0.6230 - loss: 1.0210 - val_accuracy: 0.6937 - val_loss: 0.8617 - learning_rate: 1.5000e-04
# Epoch 36/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 407ms/step - accuracy: 0.6195 - loss: 1.0204 - val_accuracy: 0.7004 - val_loss: 0.8502 - learning_rate: 1.5000e-04
# Epoch 37/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 408ms/step - accuracy: 0.6125 - loss: 1.0334 - val_accuracy: 0.6937 - val_loss: 0.8595 - learning_rate: 1.5000e-04
# Epoch 38/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 409ms/step - accuracy: 0.6182 - loss: 1.0189 - val_accuracy: 0.7061 - val_loss: 0.8466 - learning_rate: 1.5000e-04
# Epoch 39/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 407ms/step - accuracy: 0.6174 - loss: 1.0186 - val_accuracy: 0.7033 - val_loss: 0.8444 - learning_rate: 1.5000e-04
# Epoch 40/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 408ms/step - accuracy: 0.6212 - loss: 1.0082 - val_accuracy: 0.7008 - val_loss: 0.8500 - learning_rate: 1.5000e-04
# Epoch 41/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6149 - loss: 1.0204 - val_accuracy: 0.7004 - val_loss: 0.8478 - learning_rate: 1.5000e-04
# Epoch 42/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6295 - loss: 0.9942 - val_accuracy: 0.7029 - val_loss: 0.8582 - learning_rate: 1.5000e-04
# Epoch 43/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 409ms/step - accuracy: 0.6207 - loss: 1.0189 - val_accuracy: 0.7083 - val_loss: 0.8486 - learning_rate: 1.5000e-04
# Epoch 44/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 407ms/step - accuracy: 0.6216 - loss: 1.0084 - val_accuracy: 0.7065 - val_loss: 0.8378 - learning_rate: 1.5000e-04
# Epoch 45/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 404ms/step - accuracy: 0.6277 - loss: 1.0141 - val_accuracy: 0.6972 - val_loss: 0.8543 - learning_rate: 1.5000e-04
# Epoch 46/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 408ms/step - accuracy: 0.6271 - loss: 1.0016 - val_accuracy: 0.7044 - val_loss: 0.8436 - learning_rate: 1.5000e-04
# Epoch 47/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6210 - loss: 1.0103 - val_accuracy: 0.7111 - val_loss: 0.8330 - learning_rate: 1.5000e-04
# Epoch 48/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6345 - loss: 0.9859 - val_accuracy: 0.7086 - val_loss: 0.8359 - learning_rate: 1.5000e-04
# Epoch 49/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.6309 - loss: 0.9987 - val_accuracy: 0.7068 - val_loss: 0.8392 - learning_rate: 1.5000e-04
# Epoch 50/50
# 350/351 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.6182 - loss: 1.0118
# Epoch 50: saving model to ResNet101_best_model_epoch_50.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 148s 414ms/step - accuracy: 0.6183 - loss: 1.0118 - val_accuracy: 0.7083 - val_loss: 0.8273 - learning_rate: 1.5000e-04
# Restoring model weights from the end of the best epoch: 50.
#
# --- Evaluating ResNet101 Set ---
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 11s 121ms/step - accuracy: 0.7287 - loss: 0.7608
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 19s 149ms/step
#
# Metrics for ResNet101 Set:
# Loss: 0.843
# Accuracy: 0.700
# Precision: 0.700
# Recall: 0.700
# F1 Score: 0.698
# AUC: 0.933

# %% [markdown]
# **Inference**:
# - The model shows steady learning with validation accuracy reaching ~72%
# - There's a consistent gap between training and validation performance
# - It seems like the model tends to achieve good accuracy if trained for more epochs

# %% [markdown]
# ## EfficientnetB0

# %% [markdown]
# ### Note:
# Despite multiple optimization attempts with learning rate adjustments and model tuning, it still ended up with low accuracy and poor performance. I have made some observations which you'll find below

# %%
def train_efficientnetb0(train_generator, validation_generator, test_generator):
    tf.keras.backend.clear_session()
    with tf.device('/GPU:0'):
      model = create_model(EfficientNetB0, learning_rate=3e-4)
      history = train_model(model, "EfficientNetB0", train_generator, validation_generator)

      # Evaluate and plot
      metrics = evaluate_model(model, test_generator, "EfficientNetB0")
      plot_learning_curves(history, "EfficientNetB0")

      return model, history, metrics

efficientnetb0_model, efficientnetb0_history, efficientnetb0_metrics = train_efficientnetb0(train_generator, validation_generator, test_generator)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# --- Training EfficientNetB0 Model ---
# Epoch 1/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 187s 466ms/step - accuracy: 0.1668 - loss: 2.2581 - val_accuracy: 0.1698 - val_loss: 2.1517 - learning_rate: 3.0000e-04
# Epoch 2/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 404ms/step - accuracy: 0.1804 - loss: 2.1739 - val_accuracy: 0.1690 - val_loss: 2.0787 - learning_rate: 3.0000e-04
# Epoch 3/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.1911 - loss: 2.1002 - val_accuracy: 0.1840 - val_loss: 2.0084 - learning_rate: 3.0000e-04
# Epoch 4/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 407ms/step - accuracy: 0.1871 - loss: 2.0439 - val_accuracy: 0.1619 - val_loss: 1.9826 - learning_rate: 3.0000e-04
# Epoch 5/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.1944 - loss: 1.9958 - val_accuracy: 0.1698 - val_loss: 1.9524 - learning_rate: 3.0000e-04
# Epoch 6/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 146s 408ms/step - accuracy: 0.1937 - loss: 1.9534 - val_accuracy: 0.1626 - val_loss: 1.9086 - learning_rate: 3.0000e-04
# Epoch 7/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.2056 - loss: 1.9156 - val_accuracy: 0.1619 - val_loss: 1.8924 - learning_rate: 3.0000e-04
# Epoch 8/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.2080 - loss: 1.8810 - val_accuracy: 0.1626 - val_loss: 1.8734 - learning_rate: 3.0000e-04
# Epoch 9/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 404ms/step - accuracy: 0.2103 - loss: 1.8628 - val_accuracy: 0.1723 - val_loss: 1.8629 - learning_rate: 3.0000e-04
# Epoch 10/50
# 348/351 ━━━━━━━━━━━━━━━━━━━━ 1s 385ms/step - accuracy: 0.2048 - loss: 1.8439
# Epoch 10: saving model to EfficientNetB0_best_model_epoch_10.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.2049 - loss: 1.8438 - val_accuracy: 0.1708 - val_loss: 1.8610 - learning_rate: 3.0000e-04
# Epoch 11/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.2144 - loss: 1.8302 - val_accuracy: 0.1694 - val_loss: 1.9665 - learning_rate: 3.0000e-04
# Epoch 12/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.2147 - loss: 1.8117 - val_accuracy: 0.1616 - val_loss: 1.8777 - learning_rate: 3.0000e-04
# Epoch 13/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.2067 - loss: 1.8142 - val_accuracy: 0.1619 - val_loss: 1.9014 - learning_rate: 3.0000e-04
# Epoch 14/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 404ms/step - accuracy: 0.2185 - loss: 1.8012 - val_accuracy: 0.1694 - val_loss: 1.8444 - learning_rate: 3.0000e-04
# Epoch 15/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 402ms/step - accuracy: 0.2214 - loss: 1.7860 - val_accuracy: 0.1623 - val_loss: 1.8451 - learning_rate: 3.0000e-04
# Epoch 16/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.2136 - loss: 1.7907 - val_accuracy: 0.1608 - val_loss: 1.8649 - learning_rate: 3.0000e-04
# Epoch 17/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.2100 - loss: 1.7783 - val_accuracy: 0.1619 - val_loss: 1.8723 - learning_rate: 3.0000e-04
# Epoch 18/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 404ms/step - accuracy: 0.2200 - loss: 1.7753 - val_accuracy: 0.1637 - val_loss: 1.8665 - learning_rate: 3.0000e-04
# Epoch 19/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.2241 - loss: 1.7709
# Epoch 19: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.2241 - loss: 1.7709 - val_accuracy: 0.1633 - val_loss: 1.9659 - learning_rate: 3.0000e-04
# Epoch 20/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.2231 - loss: 1.7604 - val_accuracy: 0.1616 - val_loss: 1.8900 - learning_rate: 9.0000e-05
# Epoch 21/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.2361 - loss: 1.7520 - val_accuracy: 0.1616 - val_loss: 1.8938 - learning_rate: 9.0000e-05
# Epoch 21: early stopping
# Restoring model weights from the end of the best epoch: 14.
#
# --- Evaluating EfficientNetB0 Set ---
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 14s 149ms/step - accuracy: 0.2189 - loss: 1.6965
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 20s 152ms/step
#
# Metrics for EfficientNetB0 Set:
# Loss: 1.858
# Accuracy: 0.167
# Precision: 0.049
# Recall: 0.167
# F1 Score: 0.076
# AUC: 0.728

# %% [markdown]
# #### **Inference**:
# EfficientNetB0 struggled to learn meaningful features for this classification task, suggesting the need for model architecture adjustments, enhanced data preparation, or exploration of alternative models.<br><hr>
# Also, I feel the following:
# - Significantly lower accuracy (~22%)
# - Unstable validation performance
# - Signs of overfitting

# %% [markdown]
# ### VGG16

# %%
def train_vgg16(train_generator, validation_generator, test_generator):
    tf.keras.backend.clear_session()
    tf.random.set_seed(42)
    with tf.device('/GPU:0'):
      model = create_model(VGG16, learning_rate=1e-3)
      history = train_model(model, "VGG16", train_generator, validation_generator)

      # Evaluate and plot
      metrics = evaluate_model(model, test_generator, "VGG16")
      plot_learning_curves(history, "VGG16")

      return model, history, metrics

vgg16_model, vgg16_history, vgg16_metrics = train_vgg16(train_generator, validation_generator, test_generator)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# --- Training VGG16 Model ---
# Epoch 1/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 156s 421ms/step - accuracy: 0.7151 - loss: 1.0588 - val_accuracy: 0.8502 - val_loss: 0.6469 - learning_rate: 0.0010
# Epoch 2/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 404ms/step - accuracy: 0.8084 - loss: 0.7297 - val_accuracy: 0.8563 - val_loss: 0.5693 - learning_rate: 0.0010
# Epoch 3/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.8307 - loss: 0.6272 - val_accuracy: 0.8641 - val_loss: 0.5332 - learning_rate: 0.0010
# Epoch 4/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 402ms/step - accuracy: 0.8231 - loss: 0.6043 - val_accuracy: 0.8723 - val_loss: 0.4894 - learning_rate: 0.0010
# Epoch 5/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.8347 - loss: 0.5579 - val_accuracy: 0.8620 - val_loss: 0.4907 - learning_rate: 0.0010
# Epoch 6/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 404ms/step - accuracy: 0.8348 - loss: 0.5498 - val_accuracy: 0.8738 - val_loss: 0.4695 - learning_rate: 0.0010
# Epoch 7/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.8338 - loss: 0.5313 - val_accuracy: 0.8538 - val_loss: 0.4943 - learning_rate: 0.0010
# Epoch 8/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.8355 - loss: 0.5254 - val_accuracy: 0.8684 - val_loss: 0.4504 - learning_rate: 0.0010
# Epoch 9/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 402ms/step - accuracy: 0.8442 - loss: 0.5174 - val_accuracy: 0.8449 - val_loss: 0.5013 - learning_rate: 0.0010
# Epoch 10/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 404ms/step - accuracy: 0.8443 - loss: 0.5072 - val_accuracy: 0.8573 - val_loss: 0.4636 - learning_rate: 0.0010
# Epoch 11/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.8432 - loss: 0.5072 - val_accuracy: 0.8620 - val_loss: 0.4581 - learning_rate: 0.0010
# Epoch 12/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 143s 400ms/step - accuracy: 0.8572 - loss: 0.4735 - val_accuracy: 0.8613 - val_loss: 0.4685 - learning_rate: 0.0010
# Epoch 13/50
# 350/351 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.8487 - loss: 0.4946
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.8487 - loss: 0.4946 - val_accuracy: 0.8652 - val_loss: 0.4534 - learning_rate: 0.0010
# Epoch 14/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 402ms/step - accuracy: 0.8575 - loss: 0.4729 - val_accuracy: 0.8762 - val_loss: 0.4112 - learning_rate: 3.0000e-04
# Epoch 15/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 404ms/step - accuracy: 0.8659 - loss: 0.4383 - val_accuracy: 0.8698 - val_loss: 0.4149 - learning_rate: 3.0000e-04
# Epoch 16/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.8696 - loss: 0.4367 - val_accuracy: 0.8716 - val_loss: 0.4132 - learning_rate: 3.0000e-04
# Epoch 17/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 402ms/step - accuracy: 0.8560 - loss: 0.4411 - val_accuracy: 0.8713 - val_loss: 0.4098 - learning_rate: 3.0000e-04
# Epoch 18/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 404ms/step - accuracy: 0.8625 - loss: 0.4349 - val_accuracy: 0.8777 - val_loss: 0.4010 - learning_rate: 3.0000e-04
# Epoch 19/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.8579 - loss: 0.4398 - val_accuracy: 0.8762 - val_loss: 0.3967 - learning_rate: 3.0000e-04
# Epoch 20/50
# 350/351 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.8659 - loss: 0.4302
# Epoch 20: saving model to VGG16_best_model_epoch_20.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.8659 - loss: 0.4302 - val_accuracy: 0.8741 - val_loss: 0.3955 - learning_rate: 3.0000e-04
# Epoch 21/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.8668 - loss: 0.4214 - val_accuracy: 0.8698 - val_loss: 0.4042 - learning_rate: 3.0000e-04
# Epoch 22/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 143s 401ms/step - accuracy: 0.8687 - loss: 0.4136 - val_accuracy: 0.8688 - val_loss: 0.4025 - learning_rate: 3.0000e-04
# Epoch 23/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 402ms/step - accuracy: 0.8699 - loss: 0.4106 - val_accuracy: 0.8705 - val_loss: 0.4049 - learning_rate: 3.0000e-04
# Epoch 24/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.8626 - loss: 0.4129 - val_accuracy: 0.8691 - val_loss: 0.3948 - learning_rate: 3.0000e-04
# Epoch 25/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 404ms/step - accuracy: 0.8679 - loss: 0.3997 - val_accuracy: 0.8766 - val_loss: 0.3910 - learning_rate: 3.0000e-04
# Epoch 26/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 402ms/step - accuracy: 0.8705 - loss: 0.4104 - val_accuracy: 0.8773 - val_loss: 0.3916 - learning_rate: 3.0000e-04
# Epoch 27/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.8731 - loss: 0.4009 - val_accuracy: 0.8670 - val_loss: 0.4050 - learning_rate: 3.0000e-04
# Epoch 28/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 402ms/step - accuracy: 0.8744 - loss: 0.4060 - val_accuracy: 0.8798 - val_loss: 0.3873 - learning_rate: 3.0000e-04
# Epoch 29/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.8816 - loss: 0.3811 - val_accuracy: 0.8738 - val_loss: 0.3885 - learning_rate: 3.0000e-04
# Epoch 30/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.8709 - loss: 0.4020 - val_accuracy: 0.8652 - val_loss: 0.4098 - learning_rate: 3.0000e-04
# Epoch 31/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.8706 - loss: 0.4008 - val_accuracy: 0.8805 - val_loss: 0.3829 - learning_rate: 3.0000e-04
# Epoch 32/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 404ms/step - accuracy: 0.8692 - loss: 0.4049 - val_accuracy: 0.8784 - val_loss: 0.3818 - learning_rate: 3.0000e-04
# Epoch 33/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.8740 - loss: 0.3983 - val_accuracy: 0.8688 - val_loss: 0.3950 - learning_rate: 3.0000e-04
# Epoch 34/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 402ms/step - accuracy: 0.8774 - loss: 0.3897 - val_accuracy: 0.8695 - val_loss: 0.4025 - learning_rate: 3.0000e-04
# Epoch 35/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 404ms/step - accuracy: 0.8796 - loss: 0.3800 - val_accuracy: 0.8713 - val_loss: 0.3996 - learning_rate: 3.0000e-04
# Epoch 36/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 404ms/step - accuracy: 0.8800 - loss: 0.3797 - val_accuracy: 0.8716 - val_loss: 0.4000 - learning_rate: 3.0000e-04
# Epoch 37/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.8729 - loss: 0.3843 - val_accuracy: 0.8773 - val_loss: 0.3781 - learning_rate: 3.0000e-04
# Epoch 38/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 401ms/step - accuracy: 0.8852 - loss: 0.3750 - val_accuracy: 0.8787 - val_loss: 0.3800 - learning_rate: 3.0000e-04
# Epoch 39/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.8836 - loss: 0.3774 - val_accuracy: 0.8762 - val_loss: 0.3955 - learning_rate: 3.0000e-04
# Epoch 40/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 406ms/step - accuracy: 0.8788 - loss: 0.3833 - val_accuracy: 0.8741 - val_loss: 0.3955 - learning_rate: 3.0000e-04
# Epoch 41/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 404ms/step - accuracy: 0.8799 - loss: 0.3741 - val_accuracy: 0.8784 - val_loss: 0.3757 - learning_rate: 3.0000e-04
# Epoch 42/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 402ms/step - accuracy: 0.8793 - loss: 0.3831 - val_accuracy: 0.8816 - val_loss: 0.3889 - learning_rate: 3.0000e-04
# Epoch 43/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 402ms/step - accuracy: 0.8777 - loss: 0.3737 - val_accuracy: 0.8791 - val_loss: 0.3868 - learning_rate: 3.0000e-04
# Epoch 44/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 404ms/step - accuracy: 0.8753 - loss: 0.3854 - val_accuracy: 0.8798 - val_loss: 0.3831 - learning_rate: 3.0000e-04
# Epoch 45/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.8825 - loss: 0.3840 - val_accuracy: 0.8762 - val_loss: 0.3846 - learning_rate: 3.0000e-04
# Epoch 46/50
# 350/351 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.8857 - loss: 0.3707
# Epoch 46: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.8856 - loss: 0.3707 - val_accuracy: 0.8695 - val_loss: 0.3997 - learning_rate: 3.0000e-04
# Epoch 47/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.8755 - loss: 0.3785 - val_accuracy: 0.8734 - val_loss: 0.3841 - learning_rate: 9.0000e-05
# Epoch 48/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 144s 403ms/step - accuracy: 0.8874 - loss: 0.3702 - val_accuracy: 0.8805 - val_loss: 0.3741 - learning_rate: 9.0000e-05
# Epoch 49/50
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.8907 - loss: 0.3526 - val_accuracy: 0.8798 - val_loss: 0.3772 - learning_rate: 9.0000e-05
# Epoch 50/50
# 350/351 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.8938 - loss: 0.3446
# Epoch 50: saving model to VGG16_best_model_epoch_50.keras
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 145s 405ms/step - accuracy: 0.8938 - loss: 0.3446 - val_accuracy: 0.8809 - val_loss: 0.3719 - learning_rate: 9.0000e-05
# Restoring model weights from the end of the best epoch: 50.
#
# --- Evaluating VGG16 Set ---
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 11s 116ms/step - accuracy: 0.9007 - loss: 0.3225
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 10s 96ms/step
#
# Metrics for VGG16 Set:
# Loss: 0.356
# Accuracy: 0.886
# Precision: 0.886
# Recall: 0.886
# F1 Score: 0.886
# AUC: 0.988

# %% [markdown]
# <br><hr>
# - Training accuracy steadily improves, reaching about 89% by the final epoch, while validation accuracy peaks at around 88%.
# - The loss curves show a consistent decrease, with both training and validation loss converging to approximately 0.35–0.40.
# - These suggest that VGG16 effectively learns the dataset's features and generalizes well to unseen data.

# %% [markdown]
# ## Model Comparisions

# %% [markdown]
# v. Report training, validation, and test Precision, Recall, AUC, and F1 score for
# those models. Is there a model that clearly outperforms others? Remember
# that this is a multi-class classification problem.

# %%
def compare_models(model_results):
    print("\nModel Comparison:")
    print("Model\t\tPrecision\tRecall\t\tF1 Score\tAUC")
    print("-" * 80)

    results_summary = []
    for model_name, metrics in model_results.items():
        # metrics are: loss, accuracy, precision, recall, f1, auc
        print(f"{model_name:<12}\t{metrics[2]:.4f}\t\t{metrics[3]:.4f}\t\t{metrics[4]:.4f}\t\t{metrics[5]:.4f}")
        results_summary.append({
            'model_name': model_name,
            'precision': metrics[2],
            'recall': metrics[3],
            'f1_score': metrics[4],
            'auc': metrics[5]
        })
    best_model = max(results_summary, key=lambda x: x['f1_score'])
    print(f"\nBest performing model based on F1 Score: {best_model['model_name']}")


model_results = {
    'ResNet50': resnet50_metrics,
    'ResNet101V2': resnet101_metrics,
    'EfficientNetB0': efficientnetb0_metrics,
    'VGG16': vgg16_metrics
}
compare_models(model_results)
# Out:
# Model Comparison:
# Model		Precision	Recall		F1 Score	AUC
# --------------------------------------------------------------------------------
# ResNet50    	0.7306		0.7280		0.7262		0.9441
# ResNet101V2 	0.7003		0.6997		0.6979		0.9333
# EfficientNetB0	0.0494		0.1673		0.0761		0.7283
# VGG16       	0.8863		0.8857		0.8856		0.9881
#
# Best performing model based on F1 Score: VGG16

# %% [markdown]
# ## **Final Obseravtion**:
# The VGG16 model outperformed the other models with the highest F1 Score of 0.8856 and an AUC of 0.9881, indicating excellent performance. ResNet variants also performed well with an F1 Score and AUC. EfficientNetB0 had the lowest performance, with significantly lower precision, recall, and F1 Score. Overall, ```VGG16``` is the best model for this image classification task based on the evaluation metrics.
